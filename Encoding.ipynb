# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Satyam\Downloads\100-days-of-machine-learning-main\day26-ordinal-encoding\customer.csv')

# %%
df
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
df['review'].unique()
# Out:
# array(['Average', 'Poor', 'Good'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
df["review"] = enc.fit_transform(df[["review"]])
# df["education"] = enc.fit_transform(df[["education"]])

# %%
df
# Out:
#     age  gender  review education purchased
# 0    30  Female     0.0    School        No
# 1    68  Female     2.0        UG        No
# 2    70  Female     1.0        PG        No
# 3    72  Female     1.0        PG        No
# 4    16  Female     0.0        UG        No
# 5    31  Female     0.0    School       Yes
# 6    18    Male     1.0    School        No
# 7    60  Female     2.0    School       Yes
# 8    65  Female     0.0        UG        No
# 9    74    Male     1.0        UG       Yes
# 10   98  Female     1.0        UG       Yes
# 11   74    Male     1.0        UG       Yes
# 12   51    Male     2.0    School        No
# 13   57  Female     0.0    School        No
# 14   15    Male     2.0        PG       Yes
# 15   75    Male     2.0        UG        No
# 16   59    Male     2.0        UG       Yes
# 17   22  Female     2.0        UG       Yes
# 18   19    Male     1.0    School        No
# 19   97    Male     2.0        PG       Yes
# ...
